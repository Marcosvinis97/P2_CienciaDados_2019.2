# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# Nome: Cicero Tiago Carneiro Valentim
#
# Nome: Luiz Felipe Lazzaron
#
# Nome: Marcos Vinícius da Silva

# %% [markdown]
# Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# # Classificador automático de sentimento

# %% [markdown]
# ## Preparando o ambiente no jupyter:

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %% [markdown]
# ___
# ## Autenticando no  Twitter
#
# * Conta: ***@CiceroTiagoCar3***

# %%
# @CiceroTiagoCar3

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ___
# ## Etapas do projeto:

# %% [markdown]
# ### Escolha de um produto e coleta das mensagens

# %%
#Produto escolhido:
produto = 'depressao'

#Quantidade mínima de mensagens capturadas:
n = 250
#Quantidade mínima de mensagens para a base de treinamento:
t = 150

#Filtro de língua, escolha uma na tabela ISO 639-1.
lang = 'pt'

# %% [markdown]
# Capturando os dados do twitter:

# %%
msgs = []

# %%
#Cria um objeto para a captura
api = tweepy.API(auth)

#Inicia a captura, para mais detalhes: ver a documentação do tweepy
i = 1
for msg in tweepy.Cursor(api.search, q="{0} -filter:retweets".format(produto), lang=lang, tweet_mode="extended").items():
    new_msg = { 'User Name': msg.user.name,
                'Tweet Created At': msg.created_at,
                'Tweet Text': msg.full_text.lower(),
                'User Location': msg.user.location,
                'Phone Type': msg.source,
                'Favorite Count': msg.favorite_count,
                'Retweets':msg.retweet_count
                }
    if new_msg not in 
    msgs.append(new_msg)
    i += 1
    if i > n:
        break

#Embaralhando as mensagens para reduzir um possível viés
shuffle(msgs)

# %%
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(msgs)
# Out:
#      Favorite Count                       Phone Type  Retweets  \
# 0    1               Twitter for iPhone               0
# 1    0               Twitter for Android              0
# 2    0               Twitter for Android              0
# 3    0               Twitter for Android              0
# 4    2               Twitter Web App                  0
# 5    1               Twitter for Android              0
# 6    0               Twitter for Android              0
# 7    2               Twitter for Android              0
# 8    3               Twitter for Android              0
# 9    0               Twitter for Android              0
# 10   0               Twitter for Android              0
# 11   1               Twitter for Android              0
# 12   0               Twitter for iPhone               0
# 13   0               Twitter for Android              0
# 14   2               Twitter for Android              1
# 15   0               Twitter for Android              0
# 16   13              Twitter Web App                  0
# 17   0               Twitter for Android              0
# 18   0               Twitter for Android              0
# 19   0               Twitter for Android              0
# 20   0               Twitter for iPhone               0
# 21   2               Twitter for iPhone               2
# 22   1               Twitter for iPhone               0
# 23   1               Twitter for iPhone               0
# 24   0               Twitter for Android              0
# 25   0               Twitter Web Client               0
# 26   0               Twitter for iPhone               0
# 27   0               Mundiware Elite CS               0
# 28   0               Facebook                         0
# 29   0               Twitter Web App                  0
# ..  ..                           ...                 ..
# 470  1               Twitter for Android              0
# 471  0               Twitter for Android              0
# 472  1               Twitter for iPhone               0
# 488  sabe o fundo do poço?\n\neu já estive lá\n\ne queria dizer pra vcs: busquem terapia, se cuidem, depressão é uma doença que assim como "todas" as outras tem tratamento ❤️ \n\nnão é o fim pra você, fique vivo, por mais que as vezes pareça que não, vale a pena continuar. https://t.co/b2e8md47yc
# 489  sim, eu tenho depressão.
# 490  hoje é dia de prevenção ao suicídio.\n\ndepressão é coisa séria, e não esses risquisinhos nos braços e nas pernas q umas emocionadas fazem, e fica publicando na rede social só pra geral se preocupar e quando vai ver não é nada, só fogo no c*. \ndepressão é muito mais doq isso!
# 491  quando era teste de biologia no estadual a rapazeada saia era cm depressao https://t.co/pvqswtroym
# 492  so quem tem familiar com depressao sabe a merda que é
# 493  durante algum tempo, eu tive diversos problemas psicológicos e por conta disso, desde os meus 15 anos, eu frequento psicólogo. porém, aos meus 18 anos, aconteceu algo na minha vida e isso foi um gatilho para depressão.
# 494  diante disso, os pais entregaram fitas amarelas e mensagens no funeral de mike. a partir desse dia, começou a campanha de prevenção da depressão e do suicídio. nosso país é um dos mais depressivos do mundo. #setembroamarelo (continua)...
# 495  pra mim, a pior fase da depressão não é quando a gente tá chorando sem parar e sim  a falta de sentimentos não conseguir sentir nada! nem amor,nem raiva, nem tristeza, "viver" literalmente como uma morta ...😔
# 496  quando eu estiver curada da depressão vou decretar esse dia feriado nacional
# 497  depressão é um bagulho foda né?
# 498  psicóloga fala sobre depressão no 'ab saúde' https://t.co/d4fvpfrobn
# 499  10 de setembro é o dia mundial do suicídio 💛\nbullying é preconceito que leva a depressão e até a morte dependendo de cada pessoa👍\n#xoodio\n#xopreconceito\n#menosodiomaisamoraoproximo https://t.co/wunkiopei9
#
#                       User Location                        User Name
# 0    Lille, France                   alívio cômico
# 1    26•07•18 | ▪jaguar              paola 🌈
# 2    São Paulo, Brasil               Gracy 🙊🤞⚡
# 3    Rio de Janeiro, Brasil          Davilla
# 4                                    Sapatrem
# 5    Porto Alegre, Brasil            Laura
# 6    urano                           Lilith
# 7    Petrolina, Brasil               Arruda
# 8    !♥︎ ~ bts | monsta x            「 ᴀɴᴅʏ 🦀 」
# 9                                    Igor Júnior
# 10   Samuel's Drift                  たわごと
# 11   Jardim Primavera, Duque de Cax  clara
# 12                                   sla
# 13                                   Francine Pedrosa Santos Bicalho
# 14   konoha                          👹𝔠𝔥𝔦𝔩𝔡 𝔣𝔯𝔬𝔪 𝔭𝔲𝔯𝔤𝔞𝔱𝔬𝔯𝔶
# 15   Piauí, Brasil                   lunnɑ
# 16   São Paulo-SP                    PUC-SP
# 17   Ribeirão Preto, Brasil          𝐫𝐞𝐛𝐞𝐜𝐚 𝐚𝐬 𝐚𝐥𝐞𝐱 𝐤𝐚𝐫𝐞𝐯
# 18   Portugal                        ｍａｆａｌｄａ
# 19   Ceilândia, Brasília             Giba
# 20   Hell de Janeiro                 𝐃𝐨𝐦𝐢𝐧𝐠𝐨𝐝𝐬, 𝐬𝐮𝐣𝐞𝐢𝐭𝐨 𝐝𝐞 𝐬𝐨𝐫𝐭𝐞
# 21   Portugal                        MariaJoãoAugusto
# 22                                   mãe do demogorgon
# 23                                   filipa
# 24   inferno                         yin
# 25   Jundiai - SP                    Tainan
# 26   Belo Horizonte - Brasil         Leonardo Valverde
# 27   Ponta Grossa, Brasil            ARede
# 28   São Paulo, Brasil               João Placoná
# 29                                   Thaís Glass
# ..  ..                                       ...
# 470  Springfield, #OscarPerez        titto
# 471                                  Moi ✾
# 472                                  indec¡sa 🍑
# 473  Boa Vista                       Su
# 474                                  Arauto
# 475  ele/dele                        mat
# 476                                  Quem imaginava?
# 477  Minas Gerais - Brasil           Érica Salazar
# 478                                  Ca🧜🏻‍♀️
# 479                                  maga
# 480  Rio de Janeiro                  Flávia Cezar
# 481                                  Rodrigo Matos
# 482  Brazil                          tg.
# 483  ♡ ana                           STREAM K-12
# 484  Rio de Janeiro, Brasil          Vitor Azevedo
# 485                                  Tata
# 486                                  executamo os cara
# 487  Asgard                          ‎ mᥲfᥲᥣdª 🏳️‍🌈
# 488  VASCO DA GAMA                   Esther Regina.
# 489                                  Jacon
# 490  Bahia, Brasil                   Satanáries💋❣
# 491  Minas Gerais                    Guilherme
# 492                                  chá de capim santo
# 493  Niterói, RJ                     Pedro
# 494  Salvador, Brazil                Allana
# 495                                  🔯
# 496                                  ؘ
# 497                                  Jovem Yasuke
# 498                                  G1 Caruaru
# 499  Barra Bonita, São Paulo         Bruna Maria
#
# [500 rows x 7 columns]

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %%
#Verifica se o arquivo não existe para não substituir um conjunto pronto
if not os.path.isfile('./{0}.xlsx'.format(produto)):
    
    #Abre o arquivo para escrita
    writer = pd.ExcelWriter('{0}.xlsx'.format(produto))

    #divide o conjunto de mensagens em duas planilhas
    dft = pd.DataFrame(msgs[:t])
    dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)

    dfc = pd.DataFrame(msgs[t:])
    dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)

    #fecha o arquivo
    writer.save()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:912: UserWarning: Ignoring URL 'https://t.co/hdtpunwqch
#
# da%20uma%20moral%20aí%20pro%20nenêm:%20eu%20numa%20entrevista%20com%20duas%20mulheres%20que%20admiro%20pakas
# minha%20psicologa%20morgana%20foda%20pra%20um%20caralho%20e%20minha%20amiga%20vulgo%20futura%20jornalista%20pika%20das%20galaxias%20@andressa1747' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %% [markdown]
# ___
# ### Classificando as mensagens na coragem
#
# Esta etapa é manual. Faça a mesma pelo Excel.

# %% [markdown]
# ___
# ### Montando o Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %% [markdown]
# ___
# ### Verificando a performance
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que periodicamente realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# # Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
